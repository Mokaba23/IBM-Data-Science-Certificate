# %%
# !pip install sqlalchemy
# !pip install ibm_db_sa
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# !pip install sql
# Out:
# ...
#   Created wheel for sql: filename=sql-0.4.0-py3-none-any.whl size=4114 sha256=8415fac37728178e24c16e5935bb8c527f6ee9f8bf3f6eca9a40a43ad30618c3
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/17/4b/40/33a7ed9e9fe3cd614b50b2803fb5aea3d8eceb35731a688b21
# Successfully built sql
# ...

# %%
# %load_ext sql
# Out:
# The sql module is not an IPython extension.

# %%
# %sql ibm_db_sa://jhl91363:NfiGGtmF3igkgxm6@fbd88901-ebdb-4a4f-a32e-9822b9fb237b.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32731/BLUDB?security=SSL
# Out:
# UsageError: Line magic function `%sql` not found.
